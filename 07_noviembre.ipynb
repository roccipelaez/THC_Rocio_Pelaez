# %% [markdown]
# <a href="https://colab.research.google.com/github/roccipelaez/THC_Rocio_Pelaez/blob/main/07_noviembre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
link="https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv"
code="?raw=true"
url=link+code
df=pd.read_csv(url,sep=",",index_col=1)

# %%
df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# 2014-09-05                    362.0
# ...                             ...
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0
#
# [2484 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['No. of confirmed cases'].plot(kind='hist', bins=20, title='No. of confirmed cases')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['No. of confirmed deaths'].plot(kind='hist', bins=20, title='No. of confirmed deaths')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='No. of confirmed cases', y='No. of confirmed deaths', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['No. of confirmed cases'].plot(kind='line', figsize=(8, 4), title='No. of confirmed cases')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['No. of confirmed deaths'].plot(kind='line', figsize=(8, 4), title='No. of confirmed deaths')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.shape
# Out:
# (2484, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 2014-08-29 to 2016-03-23
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  2484 non-null   object
#  1   No. of confirmed cases   2484 non-null   float64
#  2   No. of confirmed deaths  1648 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 142.2+ KB

# %%
df.head()
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29        Guinea                   482.0                    287.0
# 2014-08-29       Nigeria                    15.0                      6.0
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-08-29       Liberia                   322.0                    225.0
# 2014-09-05        Guinea                   604.0                    362.0

# %%
df.tail() #imprime los últimos 5 datos
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0

# %%
df.isnull().sum()
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# dtype: int64

# %%
df["Country"]
# Out:
# Date
# 2014-08-29                      Guinea
# 2014-08-29                     Nigeria
# 2014-08-29                Sierra Leone
# 2014-08-29                     Liberia
# 2014-09-05                      Guinea
#                         ...
# 2016-03-23                     Liberia
# 2016-03-23                       Italy
# 2016-03-23                     Liberia
# 2016-03-23                     Nigeria
# 2016-03-23    United States of America
# Name: Country, Length: 2484, dtype: object

# %%
df["Country"].isin(["Mexico"])
# Out:
# Date
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29    False
# 2014-09-05    False
#               ...
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# Name: Country, Length: 2484, dtype: bool

# %%
df["Country"].isin(["Mexico"]).sum()
# Out:
# 0

# %%
SL=df[df["Country"]=="Sierra Leone"]

# %%
df["Country"]=="Sierra Leone"
# Out:
# Date
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29     True
# 2014-08-29    False
# 2014-09-05    False
#               ...
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# Name: Country, Length: 2484, dtype: bool

# %%
SL
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-09-05  Sierra Leone                  1146.0                    443.0
# 2014-09-08  Sierra Leone                  1234.0                    461.0
# 2014-09-12  Sierra Leone                  1287.0                    478.0
# 2014-09-16  Sierra Leone                  1464.0                    514.0
# ...                  ...                     ...                      ...
# 2015-12-17  Sierra Leone                  8704.0                   3589.0
# 2015-12-22  Sierra Leone                  8704.0                   3589.0
# 2015-12-23  Sierra Leone                  8704.0                   3589.0
# 2015-12-29  Sierra Leone                  8704.0                   3589.0
# 2016-03-23  Sierra Leone                  8704.0                   3589.0
#
# [259 rows x 3 columns]

# %%
SL=SL.drop("Country",axis=1)

# %%
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29                   935.0                    380.0
# 2014-09-05                  1146.0                    443.0
# 2014-09-08                  1234.0                    461.0
# 2014-09-12                  1287.0                    478.0
# 2014-09-16                  1464.0                    514.0

# %%
SL.shape #Tamaño de la base, 259 datos y dos columnas
# Out:
# (259, 2)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    2
# dtype: int64

# %%
SL.fillna(0.0,inplace=True)

# %%
SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    0
# dtype: int64

# %%
SL["No. of confirmed deaths"].mean()
# Out:
# 3081.019305019305

# %%
SL["No. of confirmed cases"].mean()
# Out:
# 7883.671814671815

# %%
Dates=SL.index[0:-1:10]
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

# %%
plt.plot(Dates,NCC,"d--m",ms=4,label="Infectados")
plt.plot(Dates,NCD,"d--k",ms=4,label="Decesos")
plt.grid()
plt.title("Avance del ébola en Sierra Leona")
plt.ylabel("Casos confirmados")
plt.xlabel("Periodo de tiempo")
plt.xticks(rotation=90,fontsize=8)
plt.legend()
plt.show()

# %%
PIvsD=100*SL["No. of confirmed deaths"]/SL["No. of confirmed cases"] #Calcula el porcentaje
PIvsD
# Out:
# Date
# 2014-08-29    40.641711
# 2014-09-05    38.656195
# 2014-09-08    37.358185
# 2014-09-12    37.140637
# 2014-09-16    35.109290
#                 ...
# 2015-12-17    41.233915
# 2015-12-22    41.233915
# 2015-12-23    41.233915
# 2015-12-29    41.233915
# 2016-03-23    41.233915
# Length: 259, dtype: float64

# %%
SL["PIvsD"]=PIvsD
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290

# %%
recuperados=((100-PIvsD)/100)*SL["No. of confirmed cases"]
recuperados
# Out:
# Date
# 2014-08-29     555.0
# 2014-09-05     703.0
# 2014-09-08     773.0
# 2014-09-12     809.0
# 2014-09-16     950.0
#                ...
# 2015-12-17    5115.0
# 2015-12-22    5115.0
# 2015-12-23    5115.0
# 2015-12-29    5115.0
# 2016-03-23    5115.0
# Length: 259, dtype: float64

# %%
SL["recuperados"]=recuperados
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD  \
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290
#
#             recuperados
# Date
# 2014-08-29        555.0
# 2014-09-05        703.0
# 2014-09-08        773.0
# 2014-09-12        809.0
# 2014-09-16        950.0
